# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import json

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_cnn = 'CNN_exp_data/'
path_gru = 'C4GRU_exp_data/'
path_lstm = 'C4LSTM_exp_data/'
valid_loss = 'valid_loss_history.json'
train_loss = 'train_loss_history.json'
train_acc = 'train_acc_history.json'
valid_acc = 'valid_acc_history.json'

# %% [markdown]
# ## cnn

# %%
f = open(path_cnn + train_loss)
cnn_tr_loss = json.load(f)
cnn_tr_loss = cnn_tr_loss['0']

f = open(path_cnn + valid_loss)
cnn_vl_loss = json.load(f)
cnn_vl_loss = cnn_vl_loss['0']

f = open(path_cnn + train_acc)
cnn_tr_acc = json.load(f)
cnn_tr_acc = cnn_tr_acc['0']

f = open(path_cnn + valid_acc)
cnn_vl_acc = json.load(f)
cnn_vl_acc = cnn_vl_acc['0']

plt.plot(cnn_tr_loss)
plt.plot(cnn_vl_loss)
plt.xlabel('Epoch Num')
plt.ylabel('Loss')
plt.legend(['Train Loss','Valid Loss'])
# plt.title('Optimized CNN, dropout = 0.5, test acc = 73.1%')
plt.title('Train & Valid Loss of Optimized CNN')
plt.show()

plt.plot(cnn_tr_acc)
plt.plot(cnn_vl_acc)
plt.xlabel('Epoch Num')
plt.ylabel('Accuracy')
plt.legend(['Train Acc','Valid Acc'])
# plt.title('Optimized CNN, dropout = 0.5, test acc = 73.1%')
plt.title('Train & Valid Acc of Optimized CNN')
plt.show()

# %%
f = open(path_gru + train_loss)
gru_tr_loss = json.load(f)
gru_tr_loss = gru_tr_loss['0']

f = open(path_gru + valid_loss)
gru_vl_loss = json.load(f)
gru_vl_loss = gru_vl_loss['0']

f = open(path_gru + train_acc)
gru_tr_acc = json.load(f)
gru_tr_acc = gru_tr_acc['0']

f = open(path_gru + valid_acc)
gru_vl_acc = json.load(f)
gru_vl_acc = gru_vl_acc['0']

plt.plot(cnn_tr_loss)
plt.plot(cnn_vl_loss)
plt.xlabel('Epoch Num')
plt.ylabel('Loss')
plt.legend(['Train Loss','Valid Loss'])
plt.title('Train & Valid Loss of Optimized CNN+GRU')
# plt.title('Optimized CNN + GRU, dropout = 0.5, num_stack = 4, test acc = 73.1%')
plt.show()

plt.plot(cnn_tr_acc)
plt.plot(cnn_vl_acc)
plt.xlabel('Epoch Num')
plt.ylabel('Accuracy')
plt.legend(['Train Acc','Valid Acc'])
plt.title('Train & Valid Acc of Optimized CNN+GRU')
plt.show()

# %%
f = open(path_lstm + train_loss)
lstm_tr_loss = json.load(f)
lstm_tr_loss = lstm_tr_loss['0']

f = open(path_lstm + valid_loss)
lstm_vl_loss = json.load(f)
lstm_vl_loss = lstm_vl_loss['0']

f = open(path_lstm + train_acc)
lstm_tr_acc = json.load(f)
lstm_tr_acc = lstm_tr_acc['0']

f = open(path_lstm + valid_acc)
lstm_vl_acc = json.load(f)
lstm_vl_acc = lstm_vl_acc['0']

plt.plot(cnn_tr_loss)
plt.plot(cnn_vl_loss)
plt.xlabel('Epoch Num')
plt.ylabel('Loss')
plt.legend(['Train Loss','Valid Loss'])
plt.title('Train & Valid Loss of Optimized CNN+LSTM')
# plt.title('Optimized CNN + GRU, dropout = 0.5, num_stack = 4, test acc = 73.1%')
plt.show()

plt.plot(cnn_tr_acc)
plt.plot(cnn_vl_acc)
plt.xlabel('Epoch Num')
plt.ylabel('Accuracy')
plt.legend(['Train Acc','Valid Acc'])
plt.title('Train & Valid Acc of Optimized CNN+LSTM')
plt.show()

# %%
plt.plot(cnn_tr_loss)
plt.plot(gru_tr_loss)
plt.plot(lstm_tr_loss)
plt.plot(cnn_vl_loss)
plt.plot(gru_vl_loss)
plt.plot(lstm_vl_loss)
plt.xlabel('Epoch Num')
plt.ylabel('Training & Validation Loss')
plt.title('Train & Valid Loss of 3 models')
plt.legend(['Train Loss of CNN','Train Loss of CNN+GRU', 'Train Loss of CNN+LSTM', 'Val Loss of CNN','Val Loss of CNN+GRU', 'Val Loss of CNN+LSTM'])
plt.show()

plt.plot(cnn_tr_acc)
plt.plot(gru_tr_acc)
plt.plot(lstm_tr_acc)
plt.plot(cnn_vl_acc)
plt.plot(gru_vl_acc)
plt.plot(lstm_vl_acc)
plt.xlabel('Epoch Num')
plt.ylabel('Training & Validation Acc')
plt.title('Train & Valid Acc of 3 models')
plt.legend(['Train Acc of CNN','Train Acc of CNN+GRU', 'Train Acc of CNN+LSTM', 'Val Acc of CNN','Val Acc of CNN+GRU', 'Val Acc of CNN+LSTM'])
plt.show()

# %%
CNN = [[(0.5, 50), 70.76750183105469], [(0.5, 60), 71.72686767578125], [(0.5, 70), 74.66140747070312], [(0.5, 80), 70.20316314697266], 
[(0.5, 90), 72.34762573242188], [(0.5, 100), 71.89616394042969], [(0.5, 110), 72.12190246582031], [(0.5, 120), 72.34762573242188], 
[(0.5, 130), 71.33182525634766], [(0.5, 140), 71.38825988769531], [(0.5, 150), 72.46049499511719], [(0.6, 50), 68.79232788085938], 
[(0.6, 60), 70.09029388427734], [(0.6, 70), 71.72686767578125], [(0.6, 80), 70.20316314697266], [(0.6, 90), 71.83972930908203], 
[(0.6, 100), 71.83972930908203], [(0.6, 110), 69.69526672363281], [(0.6, 120), 69.41309356689453], [(0.6, 130), 72.12190246582031], 
[(0.6, 140), 72.51692962646484], [(0.6, 150), 72.2347640991211], [(0.7000000000000001, 50), 61.568851470947266], [(0.7000000000000001, 60), 65.18058776855469], 
[(0.7000000000000001, 70), 65.23702239990234], [(0.7000000000000001, 80), 68.11512756347656], 
[(0.7000000000000001, 90), 67.21218872070312], [(0.7000000000000001, 100), 71.27539825439453], 
[(0.7000000000000001, 110), 69.75169372558594], [(0.7000000000000001, 120), 68.34085845947266], 
[(0.7000000000000001, 130), 68.73589324951172], [(0.7000000000000001, 140), 71.10609436035156], 
[(0.7000000000000001, 150), 68.84876251220703], [(0.8, 50), 47.911964416503906], [(0.8, 60), 48.08126449584961], 
[(0.8, 70), 48.363433837890625], [(0.8, 80), 49.83070373535156], [(0.8, 90), 50.45146942138672], 
[(0.8, 100), 49.88713455200195], [(0.8, 110), 50.39503479003906], [(0.8, 120), 54.23250961303711], 
[(0.8, 130), 54.06320571899414], [(0.8, 140), 55.47404479980469], [(0.8, 150), 55.07900619506836]]

drop_5 = []
drop_6 = []
drop_7 = []
drop_8 = []
for element in CNN:
    key = element[0]
    Acc = element[1]
    drop_p,epoch = key
    if drop_p == 0.5:
        drop_5.append([epoch,Acc])
    elif drop_p == 0.6:
        drop_6.append([epoch,Acc])
    elif drop_p == 0.7000000000000001:
        drop_7.append([epoch,Acc])
    elif drop_p == 0.8:
        drop_8.append([epoch,Acc])

drop_5 = np.array(drop_5)
drop_6 = np.array(drop_6)
drop_7 = np.array(drop_7)
drop_8 = np.array(drop_8)

plt.plot(drop_5[:,0],drop_5[:,1],'-o')
plt.plot(drop_6[:,0],drop_6[:,1],'-o')
plt.plot(drop_7[:,0],drop_7[:,1],'-o')
plt.plot(drop_8[:,0],drop_8[:,1],'-o')
plt.xlabel('Epoch Num')
plt.ylabel('Test Accuracy')
plt.legend(['dropout=0.5','dropout=0.6','dropout=0.7','dropout=0.8'])
plt.title('Effect of dropout and epoch number on CNN Test Accuracy')
plt.show()

# %%
LSTM =[[(2, 50), 66.0835189819336], [(2, 60), 65.06771850585938], [(2, 70), 65.97064971923828], 
[(2, 80), 67.77652740478516], [(2, 90), 64.55982208251953], [(2, 100), 63.656883239746094], 
[(2, 110), 66.30925750732422], [(2, 120), 65.6320571899414], [(2, 130), 64.33409118652344], 
[(2, 140), 64.95484924316406], [(2, 150), 67.26862335205078], [(3, 50), 66.0835189819336], 
[(3, 60), 67.09932708740234], [(3, 70), 66.47855377197266], [(3, 80), 68.79232788085938], 
[(3, 90), 65.01128387451172], [(3, 100), 68.34085845947266], [(3, 110), 65.80136108398438], 
[(3, 120), 65.68849182128906], [(3, 130), 66.70429229736328], [(3, 140), 67.09932708740234], 
[(3, 150), 67.21218872070312], [(4, 50), 64.50338745117188], [(4, 60), 65.34989166259766], 
[(4, 70), 65.8577880859375], [(4, 80), 69.92098999023438], [(4, 90), 66.422119140625], 
[(4, 100), 66.13995361328125], [(4, 110), 66.87358856201172], [(4, 120), 68.39729309082031], 
[(4, 130), 67.32505798339844], [(4, 140), 69.13092803955078], [(4, 150), 67.60722351074219], 
[(5, 50), 65.29345703125], [(5, 60), 65.74492645263672], [(5, 70), 65.97064971923828], 
[(5, 80), 65.80136108398438], [(5, 90), 67.77652740478516], [(5, 100), 66.36569213867188], 
[(5, 110), 66.25282287597656], [(5, 120), 66.1963882446289], [(5, 130), 65.40632629394531], 
[(5, 140), 66.53498840332031], [(5, 150), 69.18736267089844]]

drop_2 = []
drop_3 = []
drop_4 = []
drop_5 = []
for element in LSTM:
    key = element[0]
    Acc = element[1]
    drop_p,epoch = key
    if drop_p == 2:
        drop_2.append([epoch,Acc])
    elif drop_p == 3:
        drop_3.append([epoch,Acc])
    elif drop_p == 4:
        drop_4.append([epoch,Acc])
    elif drop_p == 5:
        drop_5.append([epoch,Acc])
        
drop_2 = np.array(drop_2)
drop_3 = np.array(drop_3)
drop_4 = np.array(drop_4)
drop_5 = np.array(drop_5)

plt.plot(drop_2[:,0],drop_2[:,1],'-o')
plt.plot(drop_3[:,0],drop_3[:,1],'-o')
plt.plot(drop_4[:,0],drop_4[:,1],'-o')
plt.plot(drop_5[:,0],drop_5[:,1],'-o')
plt.xlabel('Epoch Num')
plt.ylabel('Test Accuracy')
plt.legend(['2 stacks','3 stacks','4 stacks','5 stacks'])
plt.title('Effect of stacks number and epoch number on CNN+LSTM Test Accuracy')
plt.show()

# %%
GRU = [[(2, 50), 65.80136108398438], [(2, 60), 66.64785766601562], [(2, 70), 66.47855377197266], 
[(2, 80), 67.66365814208984], [(2, 90), 64.22122192382812], [(2, 100), 65.80136108398438], 
[(2, 110), 68.28443145751953], [(2, 120), 66.76072692871094], [(2, 130), 66.70429229736328], 
[(2, 140), 69.86456298828125], [(2, 150), 66.76072692871094], [(3, 50), 64.84198760986328], 
[(3, 60), 66.36569213867188], [(3, 70), 67.15576171875], [(3, 80), 68.34085845947266], 
[(3, 90), 67.7200927734375], [(3, 100), 63.431156158447266], [(3, 110), 67.04289245605469], 
[(3, 120), 68.28443145751953], [(3, 130), 67.88938903808594], [(3, 140), 70.25959777832031], 
[(3, 150), 66.47855377197266], [(4, 50), 65.57562255859375], [(4, 60), 70.71106719970703], 
[(4, 70), 66.30925750732422], [(4, 80), 67.43791961669922], [(4, 90), 67.15576171875], 
[(4, 100), 65.68849182128906], [(4, 110), 66.1963882446289], [(4, 120), 65.23702239990234], 
[(4, 130), 66.70429229736328], [(4, 140), 65.5191879272461], [(4, 150), 67.7200927734375], 
[(5, 50), 67.43791961669922], [(5, 60), 67.7200927734375], [(5, 70), 67.26862335205078], 
[(5, 80), 66.47855377197266], [(5, 90), 68.67945861816406], [(5, 100), 68.96162414550781], 
[(5, 110), 68.67945861816406], [(5, 120), 66.30925750732422], [(5, 130), 68.5101547241211], 
[(5, 140), 66.70429229736328], [(5, 150), 66.76072692871094]]

drop_2 = []
drop_3 = []
drop_4 = []
drop_5 = []
for element in GRU:
    key = element[0]
    Acc = element[1]
    drop_p,epoch = key
    if drop_p == 2:
        drop_2.append([epoch,Acc])
    elif drop_p == 3:
        drop_3.append([epoch,Acc])
    elif drop_p == 4:
        drop_4.append([epoch,Acc])
    elif drop_p == 5:
        drop_5.append([epoch,Acc])
        
drop_2 = np.array(drop_2)
drop_3 = np.array(drop_3)
drop_4 = np.array(drop_4)
drop_5 = np.array(drop_5)

plt.plot(drop_2[:,0],drop_2[:,1],'-o')
plt.plot(drop_3[:,0],drop_3[:,1],'-o')
plt.plot(drop_4[:,0],drop_4[:,1],'-o')
plt.plot(drop_5[:,0],drop_5[:,1],'-o')
plt.xlabel('Epoch Num')
plt.ylabel('Test Accuracy')
plt.legend(['2 stacks','3 stacks','4 stacks','5 stacks'])
plt.title('Effect of stacks number and epoch number on CNN+GRU Test Accuracy')
plt.show()
# Out:
# <ipython-input-35-9c5c2d9d2f13>:45: UserWarning: Legend does not support '2 stacks' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(['2 stacks','3 stacks','4 stacks','5 stacks'],'lower right')
# <ipython-input-35-9c5c2d9d2f13>:45: UserWarning: Legend does not support '3 stacks' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(['2 stacks','3 stacks','4 stacks','5 stacks'],'lower right')
# <ipython-input-35-9c5c2d9d2f13>:45: UserWarning: Legend does not support '4 stacks' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
# ...

# %%
lstm_cp = [62.0, 64.0, 68.0, 76.0, 74.46807861328125, 46.93877410888672, 62.0, 50.0, 76.59574127197266]
lstm_dp = [63.0, 63.0, 66.5, 78.0, 73.93617248535156, 54.591835021972656, 63.5, 66.99999237060547, 78.72340393066406]
gru_cp = [76.0, 59.999996185302734, 53.999996185302734, 66.0, 70.21276092529297, 65.30612182617188, 62.0, 45.999996185302734, 72.34042358398438]
gru_dp = [65.0, 62.0, 64.5, 62.5, 77.6595687866211, 60.20408248901367, 63.0, 65.5, 85.10637664794922]

plt.plot(np.linspace(1,9,9),lstm_cp)
plt.plot(np.linspace(1,9,9),lstm_dp)
plt.xlabel('Subject ID')
plt.ylabel('Test Accuracy %')
plt.legend(['Data-cropping', 'Data preprocessing'])
plt.title('Effect of Data Preprocessing on LSTM performance')
plt.show()

# %%
plt.plot(np.linspace(1,9,9),gru_cp)
plt.plot(np.linspace(1,9,9),gru_dp)
plt.xlabel('Subject ID')
plt.ylabel('Test Accuracy')
plt.legend(['Data-cropping', 'Data preprocessing'])
plt.title('Effect of Data Preprocessing on GRU performance')
plt.show()
